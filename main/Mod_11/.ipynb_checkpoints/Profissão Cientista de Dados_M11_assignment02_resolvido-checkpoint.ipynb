# %% [markdown]
# ## Árvores de regressão - exercícios 02
#
# Este exercício será uma continuação do anterior, mesma base, mesmas variáveis - vamos tentar buscar a 'melhor árvore'.
#
# A descrição das variáveis está abaixo:

# %% [markdown]
# | Variavel | Descrição|
# |-|-|
# |CRIM| taxa de crimes per-cápita da cidade |
# |ZN| proporção de terrenos residenciais zoneados para lotes com mais de 25.000 pés quadrados. |
# |INDUS| proporção de acres de negócios não varejistas por cidade |
# |CHAS |vale 1 se o terreno faz fronteira com o *Charles River*; 0 caso contrário |
# |NOX| Concentração de óxido nítrico (em partes por 10 milhões) |
# |RM| número médio de quartos por habitação |
# |AGE| proporção de unidades ocupadas pelo proprietário construídas antes de 1940 |
# |DIS| distâncias ponderadas até cinco centros de empregos de Boston |
# |RAD| índice de acessibilidade a rodovias radiais |
# |TAX| taxa de imposto sobre a propriedade de valor total por \\$10,000 |
# |PTRATIO| razão pupilo-professor da cidade |
# |B| $ 1000 (Bk - 0,63) ^ 2 $ onde Bk é a proporção de negros por cidade |
# |LSTAT| \%status inferior da população |
# |MEDV| (variável resposta) Valor mediano das casas ocupadas pelo proprietário em US $ 1.000|

# %% [markdown]
# ### Observação
# Assim como no exercícios anterior, vou carregar uma base de dados diferente por questões éticas.

# %%
# Base de dados
from sklearn.datasets import fetch_california_housing

# Para manipulação de dados e cálculos
import pandas as pd
import numpy as np
from math import pow

# Para visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt

# Para manipulação e visualização do modelo
from sklearn.tree import DecisionTreeRegressor, export_graphviz
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split

import graphviz

# Extraindo dados
housing = fetch_california_housing(as_frame=True)
housing_frame = housing.frame

# Dividindo base de dados em target x features
y = housing_frame['MedHouseVal']
X = housing_frame.copy().drop('MedHouseVal', axis=1)

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %% [markdown]
# ### 1. Execute os passos do exercício anterior, até que você tenha uma árvore de regressão predizendo o valor do imóvel na base de treinamento.

# %% [markdown]
# Assim como foi feito no exercício anterior, vamos remover a variável **AveOccup** devido a sua baixa relevância para o conjunto de dados.

# %%
X.drop('AveOccup', axis=1, inplace=True)
X.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  Latitude  Longitude
# 0  8.3252      41.0  6.984127   1.023810       322.0     37.88    -122.23
# 1  8.3014      21.0  6.238137   0.971880      2401.0     37.86    -122.22
# 2  7.2574      52.0  8.288136   1.073446       496.0     37.85    -122.24
# 3  5.6431      52.0  5.817352   1.073059       558.0     37.85    -122.25
# 4  3.8462      52.0  6.281853   1.081081       565.0     37.85    -122.25

# %% [markdown]
# Agora, vamos treinar o melhor modelo encontrado através do gráfico de comparação do **r^2** e **mse** das árvores de regressão criadas no exercício anterior.

# %%
# Função para calcular r^2
def r2(y, y_pred, mse):
    return 1 - (len(y) * mse / np.sum([pow(i - np.mean(y), 2) for i in y]))

# %%
# Dividindo base de dados em base de treino e teste
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=100)

# Criando o mesmo modelo do exercício anterior
regtree = DecisionTreeRegressor(max_depth=9, random_state=100)

# Treinando modelo com conjunto de treino
regtree.fit(x_train, y_train)

# Criando previsões com o modelo treinado
y_pred = regtree.predict(x_test)

# Colhendo r^2 e mean square erro do modelo treinado
temp = mse(y_test, y_pred)
print(r2(y_test, y_pred, temp))
print(temp)
# Out:
# 0.6983283753374621
# 0.3995507283687493

# %% [markdown]
# ### 2.  Calcule o caminho indicado pelos CCP-alfas dessa árvore.

# %%
# Extraindo valores de alfas e impureza da modelo criado
path = regtree.cost_complexity_pruning_path(x_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# Criando dataframe para melhor visualizar valores
tab = pd.DataFrame({'ccp_alpha': ccp_alphas, 'impurities': impurities})
tab.head()
# Out:
#       ccp_alpha  impurities
# 0  0.000000e+00    0.293129
# 1  2.458966e-19    0.293129
# 2  5.263704e-08    0.293129
# 3  1.330288e-07    0.293129
# 4  1.869394e-07    0.293129

# %% [markdown]
# ### 3. Paca cada valor de alpha obtido no item 2, treine uma árvore com o respectivo alfa, e guarde essa árvore em uma lista.

# %%
# Criando uma lista para armazenar o erro quadrático médio e o coeficiente de determinação por cada alfa da modelo
mses, R2 = [], []

for ccp_alpha in tab['ccp_alpha']:
    tmp_regtree = DecisionTreeRegressor(ccp_alpha=ccp_alpha, max_depth=9, random_state=100)
    tmp_regtree.fit(x_train, y_train)
    predict = tmp_regtree.predict(x_test)
    temp = mse(y_test, predict)
    mses.append(temp)
    R2.append(r2(y_test, predict, temp))

tab['mean_square_error'] = mses
tab['r^2'] = R2
tab.head()
# Out:
#       ccp_alpha  impurities  mean_square_error       r^2
# 0  0.000000e+00    0.293129           0.399551  0.698328
# 1  2.458966e-19    0.293129           0.399551  0.698328
# 2  5.263704e-08    0.293129           0.399553  0.698327
# 3  1.330288e-07    0.293129           0.399549  0.698330
# 4  1.869394e-07    0.293129           0.399534  0.698341

# %%
# Criando figura e primeiro eixo
fig1, ax1 = plt.subplots(figsize=(12, 8))

# Plotando no primeiro eixo um gráfico de linha comparando alfa com o coeficiente de determinação
ax1.plot(tab['ccp_alpha'], tab['r^2'], 'g-', label='R^2')
ax1.set_xlabel('CCP Alpha')
ax1.set_xticks([value * .01 for value in range(0, 44, 3)])
ax1.set_ylabel('R2', color='g')
ax1.set_yticks([value * .1 for value in range(0, 15, 1)])

# Criando um segundo eixo a partir do primeiro e plotando um gráfico de linha comparando alfa com o erro quadrático médio
ax2 = ax1.twinx()
ax2.plot(tab['ccp_alpha'], tab['mean_square_error'], 'b-', label='MSE')
ax2.set_ylabel('Mean Square Error', color='b')
ax2.set_yticks([value * .1 for value in range(0, 15, 1)])

# Criando um terceiro eixo a partir do primeiro e plotando um gráfico de linha comparando alfa com a impureza das folhas
ax3 = ax1.twiny()
ax3.plot(tab['ccp_alpha'], tab['impurities'], 'r-', label='Impurities')
ax3.set_xlabel('Total Leafs Impurities', color='red')
ax3.set_xticks([value * .01 for value in range(0, 50, 5)])

# Ajustando legendas
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax3.legend(loc='upper center')

# Visualizando figura
plt.show()

# %% [markdown]
# Vamos visualizar a relação dessas variáveis de forma isoladas.

# %%
# Fechando figura anterior
plt.close()

# Criando nova figura e sistema de eixos com o mesmo X
fig2, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8), sharex=True)

# Plotando em cada subplot um gráfico de linha diferente
sns.lineplot(data=tab, x='ccp_alpha', y='r^2', ax=axes[0, 0])
sns.lineplot(data=tab, x='ccp_alpha', y='mean_square_error', ax=axes[0, 1])
sns.lineplot(data=tab, x='ccp_alpha', y='impurities', ax=axes[1, 0])
sns.lineplot(data=tab, x='ccp_alpha', y='ccp_alpha', ax=axes[1, 1])

# Ajustando ticks dos gráficos
for ax in axes.flat:
    ax.set_xticks([value * .01 for value in range(0, 42, 3)]) 

# Visualizando figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Para cada árvore na lista, calcule o MSE da árvore.

# %%
tab['mean_square_error']
# Out:
# 0      0.399551
# 1      0.399551
# 2      0.399553
# 3      0.399549
# 4      0.399534
#          ...
# 377    0.701041
# 378    0.720151
# 379    0.796912
# 380    0.910624
# 381    1.325110
# Name: mean_square_error, Length: 382, dtype: float64

# %% [markdown]
# ### 5. Monte um gráfico do MSE pelo alpha, escolha um valor de alpha perto do ponto de mínimo do MSE

# %%
sns.lineplot(data=tab, x='mean_square_error', y='ccp_alpha')
# Out:
# <Axes: xlabel='mean_square_error', ylabel='ccp_alpha'>

# %% [markdown]
# ### 6. Calcule o R-quadrado dessa árvore encontrada no item acima

# %%
tab[tab['mean_square_error'] == tab['mean_square_error'].min()]
# Out:
#      ccp_alpha  impurities  mean_square_error      r^2
# 172   0.000225    0.307648           0.395575  0.70133

# %%
# Criando uma árvore separada com o alfa visto acima
new_regtree = DecisionTreeRegressor(max_depth=9, ccp_alpha=0.000225, random_state=100)
new_regtree.fit(x_train, y_train)
new_regtree
# Out:
# DecisionTreeRegressor(ccp_alpha=0.000225, max_depth=9, random_state=100)

# %% [markdown]
# ### 7. Visualize esta árvore.

# %%
dot_regtree = export_graphviz(new_regtree, out_file=None,  
                               feature_names=X.columns,   
                               filled=True, rounded=True,  
                               special_characters=True)
graph = graphviz.Source(dot_regtree)
graph

# %%
# Comparando a árvore com alfa = 0 e com o alfa atual
mse_before = mse(y_test, y_pred)
r2_before = r2(y_test, y_pred, temp)

mse_after = tab[tab['mean_square_error'] == tab['mean_square_error'].min()]['mean_square_error'].values[0]
r2_after = tab[tab['mean_square_error'] == tab['mean_square_error'].min()]['r^2'].values[0]

print('Antes: \nR2: {}\nMSE: {}\n\nDepois:\nR2: {}\nMSE: {}\n\nDiferença:\nR2: {}\nMSE: {}\n\nEm porcentagem: \nR2: {:.1f}%\nMSE: {:.1f}%'.format(r2_before, 
                                                                                                                                                  mse_before, 
                                                                                                                                                  r2_after, 
                                                                                                                                                  mse_after,
                                                                                                                                                  r2_after-r2_before,
                                                                                                                                                  mse_before-mse_after,
                                                                                                                                                  (r2_after-r2_before)*100,
                                                                                                                                                  (mse_before-mse_after)*100
                                                                                                                                                 ))
# Out:
# Antes:
# R2: -0.0004942578524966823
# MSE: 0.3995507283687493
#
# Depois:
# R2: 0.7013301864356942
# MSE: 0.3955749622950731
#
# Diferença:
# R2: 0.7018244442881909
# MSE: 0.003975766073676168
#
# Em porcentagem:
# R2: 70.2%
# MSE: 0.4%

# %% [markdown]
# Como é possível observar, no modelo treinado o impacto do alfa foi muito pequeno, levando a conclusão de que nesse caso específico, sua adição pouco alterou a eficácia do modelo.
