# %% [markdown]
# # Regressão 01 - tarefa 01

# %% [markdown]
# ### 1. Explorando a base de gorjetas
#
# a. Na aula fizemos uma regressão de ```tip``` explicada por ```net_bill```. Carregue os pacotes e a base, crie as variáveis necessárias como na aula, e reproduza esta regressão.
#
# b. Reproduza também o gráfico de dispersão dessas duas variáveis.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import statsmodels.formula.api as smf

# %%
tips = sns.load_dataset('tips')
tips['tip_pct'] =  tips['tip'] / tips['total_bill']
tips['net_bill'] = tips['total_bill'] - tips['tip']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct  net_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447     15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542      8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587     17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780     20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808     20.98

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
sns.boxplot(data=tips, x='tip', ax=ax[0])

tips['tip'] = [tip if tip <= 6 else np.nan for tip in tips['tip']]

sns.boxplot(data=tips, x='tip', ax=ax[1])
# Out:
# <Axes: xlabel='tip'>

# %%
print(tips.shape)
tips.dropna(inplace=True)
print(tips.shape)
# Out:
# (244, 9)
# (237, 9)

# %%
reg1 = smf.ols('tip ~ net_bill', data=tips).fit()
reg1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.254
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     80.16
# Date:                Thu, 13 Jun 2024   Prob (F-statistic):           1.08e-16
# Time:                        10:55:02   Log-Likelihood:                -330.50
# No. Observations:                 237   AIC:                             665.0
# Df Residuals:                     235   BIC:                             671.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6311      0.152     10.757      0.000       1.332       1.930
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
sns.scatterplot(x=tips['net_bill'], y=reg1.resid, ax=axes[0])
axes[0].axhline(y=0, color='r', linestyle='--')
axes[0].set_ylabel('Resíduo')
axes[0].set_xlabel('Conta Líquida (X)')

sns.regplot(data=tips, x='net_bill', y='tip', ax=axes[1])
axes[1].set_ylabel('Gorjeta')
axes[1].set_xlabel('Conta Líquida')

plt.show()

# %% [markdown]
# ### 2. Mudança de perspectiva
#
# Agora ajuste um modelo de regressão de ```tip_pct``` por ```net_bill```. Construa o gráfico de dispersão correspondente.

# %%
reg2 = smf.ols('tip_pct ~ net_bill', data=tips).fit()
reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tip_pct   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     75.60
# Date:                Thu, 13 Jun 2024   Prob (F-statistic):           6.07e-16
# Time:                        10:55:02   Log-Likelihood:                 359.59
# No. Observations:                 237   AIC:                            -715.2
# Df Residuals:                     235   BIC:                            -708.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2246      0.008     27.242      0.000       0.208       0.241
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
sns.scatterplot(x=tips['net_bill'], y=reg2.resid, ax=axes[0])
axes[0].axhline(y=0, color='r', linestyle='--')
axes[0].set_ylabel('Resíduo')
axes[0].set_xlabel('Conta Líquida (X)')

sns.regplot(data=tips, x='net_bill', y='tip_pct', ax=axes[1])
axes[1].set_ylabel('Gorjeta em %')
axes[1].set_xlabel('Conta Líquida')

plt.show()

# %% [markdown]
# ### 3. Comente
#
# Compare os dois gráficos e comente (de forma objetiva e suscinta) a relação entre eles e a diferença do ajuste. Podemos comparar diretamente os $R^2$s?

# %% [markdown]
# Quando criamos uma regressão usando as variáveis **tip** e **net_bill** a reta de regressão assume uma característica positiva, onde quanto maior o valor da conta líquida, maior a gorjeta. Um  compartamento oposto é encontrado quando usamos as variáveis **tip_pct** e **net_bill**. Observando o resíduo de ambos os modelos, a primeira regressão criada apresenta um padrão de dispersão mais desejável do que a segunda regressão e ainda possui um $R^2$ mais forte do que a segunda regressão, o que revela que a variável **net_bill** é mais adequada para explicar, através de um modelo, o comportamento da variável **tip**.

# %% [markdown]
# ### 4. Ajuste do modelo em outra escala
#
# Com o modelo no item 3, obtenha a preditiva do valor da gorjeta:
#   1. obtenha o valor predito ```pred``` para ```tip_pct``` (dica, veja o atributo ```reg.fittedvalues```)
#   2. obtenha o valor predito para ```tip``` como ```tip_pct * net_bill```
#   3. calcule o $R^2$ do modelo para ```tip```
#   4. compare esse $R^2$ com o do item 1

# %%
sns.regplot(data=tips, x='tip_pct', y='net_bill')
plt.plot(tips['tip_pct'], reg2.fittedvalues, 'r,--')

# %%
reg3 = smf.ols('tip ~ tip_pct * net_bill', data=tips).fit()
reg3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 1.147e+04
# Date:                Thu, 13 Jun 2024   Prob (F-statistic):          1.03e-252
# Time:                        11:01:12   Log-Likelihood:                 227.44
# No. Observations:                 237   AIC:                            -446.9
# Df Residuals:                     233   BIC:                            -433.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 12))

# Regressões
sns.regplot(data=tips, x='tip', y='net_bill', ax=axes[0, 0])
axes[0, 0].set_ylabel('Conta Líquida')
axes[0, 0].set_xlabel('Gorjeta')

sns.regplot(data=tips, x='tip', y='tip_pct', ax=axes[0, 1])
axes[0, 1].set_ylabel('Gorjeta em %')
axes[0, 1].set_xlabel('Gorjeta')

# Valores previstos
sns.regplot(x=tips['tip'], y=reg3.fittedvalues, ax=axes[1, 0])
axes[1, 0].set_ylabel('Valores Previstos (y_hat)')
axes[1, 0].set_xlabel('Valores Observados (y)')

sns.regplot(x=tips['tip'], y=reg3.fittedvalues, ax=axes[1, 1])
axes[1, 1].set_ylabel('Valores Previstos (y_hat)')
axes[1, 1].set_xlabel('Valores Observados (y)')

# Resíduos
sns.scatterplot(x=tips['net_bill'], y=reg3.resid, ax=axes[2, 0])
axes[2, 0].axhline(y=0, color='r', linestyle='--')
axes[2, 0].set_ylabel('Resíduo')
axes[2, 0].set_xlabel('Conta Líquida (X1)')

sns.scatterplot(x=tips['tip_pct'], y=reg3.resid, ax=axes[2, 1])
axes[2, 1].axhline(y=0, color='r', linestyle='--')
axes[2, 1].set_ylabel('Resíduo')
axes[2, 1].set_xlabel('Gorjeta em % (X2)')

plt.tight_layout()
plt.show()

# %%
print(str("""Os parâmetros usados na primeira regressão foram: {}\nO que resultou num R2 igual a: {:.2f}%\n\n
Os parâmetros usados na terceira regressão foram: {}\nO que resultou num R2 igual a: {:.2f}%\n\n
Como é possível observar, existe uma diferença de R2 dos dois modelos igual a {:.2f}%\n""").format(
    reg1.params.index[1:][0],
    reg1.rsquared * 100,
    [reg3.params.index[1:][i] for i in range(0, len(reg3.params.index[1:]))],
    reg3.rsquared * 100,
    (reg3.rsquared * 100) - (reg1.rsquared * 100)
))
# Out:
# Os parâmetros usados na primeira regressão foram: net_bill
# O que resultou num R2 igual a: 25.43%
#
#
# Os parâmetros usados na terceira regressão foram: ['tip_pct', 'net_bill', 'tip_pct:net_bill']
# O que resultou num R2 igual a: 99.33%
#
#
# Como é possível observar, existe uma diferença de R2 dos dois modelos igual a 73.89%
