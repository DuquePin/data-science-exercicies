# %% [markdown]
# # Regressão Logística I
# ## Tarefa I
#
# Neste exercício vamos trabalhar com a base "Heart Disease Data Set" disponível no site do [UCI](https://archive.ics.uci.edu/ml/datasets/heart+disease).
#
# Temos 303 indivíduos e vamos utilizar 13 variáveis disponíveis para prever a presença de doença cardíaca na variável ```num```(a 14$^a$ variável).
#
# A descrição das variáveis está recortada abaixo:
# - age: idade do paciente em anos
# - sex: sexo (1 = male; 0 = female)
# - cp: tipo de dor no peito
#   - 1: angina típica
#   - 2: angina atípica
#   - 3: dor não-angina
#   - 4: assintomático
# - trestbps: pressão sanguínea em repouso (em mm Hg na admissão ao hospital
# - chol: colesterol sérico em mg/dl
# - fbs: (açúcar no sangue em jejum > 120 mg/dl) (1 = True; 0 = False)
# - restecg: resultados eletrocardiográficos em repouso
#   - 0: normal
#   - 1: tendo anormalidade da onda ST-T (Inversões de onda T e / ou ST com elevação ou depressão de > 0.05 mV)
#   - 2: mostrando hipertrofia ventricular esquerda provável ou definitiva pelos critérios de Estes
# - thalach: frequência cardíaca máxima alcançada
# - exang: angina induzida por exercício(1 = sim; 0 = não)
# - oldpeak = Depressão de ST induzida por exercício em relação ao repouso
# - slope: Depressão de ST induzida por exercício em relação ao repouso
#   - 1: inclinação ascendente
#   - 2: estável
#   - 3: inclinação descendente
# - ca: número de vasos principais (0-3) coloridos por fluorosopia
# - thal: 3 = normal; 6 = defeito corrigido; 7 = defeito reversível
# - num: diagnóstico de doença cardíaga (status de doença angiográfica)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import statsmodels.formula.api as smf

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'

df = pd.read_csv(url, 
                 names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
                        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'])
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
df['flag_doente'] = (df['num'] != 0).astype('int64')
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num  flag_doente
# ...

# %% [markdown]
# 1. Monte uma bivariada para a variável ```sex``` com as seguintes estatísticas:
#
# - Número de *saudáveis*
# - Número de *doentes*
# - Total
# - Quantidade média de doentes
# - *Odds*
# - *Odds ratio* (Use o total como referência)
# - Logito (LOG(*Odds*))
# - O LOG do *Odds ratio* (com o total como referência) é chamado de *Weight of Evidence* (WOE). Calcule-o.

# %%
gp_sex = df.groupby(by='sex').agg(
    qtd_saudavel=('flag_doente', lambda x: x[x == 0].count()),
    qtd_doente=('flag_doente', lambda x: x[x == 1].count()),
    total=('flag_doente', 'count'),
    media_doente=('flag_doente', 'mean')
)
gp_sex['chance_saudavel'] = gp_sex['qtd_saudavel'] / gp_sex['qtd_doente']
gp_sex['chance_doente'] = gp_sex['qtd_doente'] / gp_sex['qtd_saudavel']
gp_sex['rc_saudavel'] = gp_sex['chance_saudavel'] * np.power(gp_sex['qtd_saudavel'] / gp_sex['total'], -1)
gp_sex['rc_doente'] = gp_sex['chance_doente'] * np.power(gp_sex['qtd_doente'] / gp_sex['total'], -1)
gp_sex['logito_doente'] = np.log(gp_sex['chance_doente'])
gp_sex['woe_saudavel'] = np.log(gp_sex['rc_saudavel'])
gp_sex['woe_doente'] = np.log(gp_sex['rc_doente'])
gp_sex.rename(index={0.0: 'F', 1.0: 'M'}, inplace=True)
gp_sex
# Out:
#      qtd_saudavel  qtd_doente  total  media_doente  chance_saudavel  \
# sex
# F              72          25     97      0.257732         2.880000
# M              92         114    206      0.553398         0.807018
#
#      chance_doente  rc_saudavel  rc_doente  logito_doente  woe_saudavel  \
# sex
# F         0.347222     3.880000   1.347222       -1.05779      1.355835
# M         1.239130     1.807018   2.239130        0.21441      0.591678
#
#      woe_doente
# sex
# F      0.298045
# M      0.806088

# %% [markdown]
# 2. Monte uma bivariada para a variável ```age``` com as seguintes estatísticas:
# - Categorize a variável em 5 grupos
# - Calcule as mesmas quantidades calculadas no execício anterior
# - Calcule também o valor médio da variável ```age```

# %%
df['cat_age'] = pd.qcut(x=df['age'], q=5)
gp_age = df.groupby(by='cat_age', observed=True).agg(
    media_idade=('age', 'mean'),
    qtd_saudavel=('flag_doente', lambda x: x[x == 0].count()),
    qtd_doente=('flag_doente', lambda x: x[x == 1].count()),
    total=('flag_doente', 'count'),
    media_doente=('flag_doente', 'mean')
)
gp_age['chance_saudavel'] = gp_age['qtd_saudavel'] / gp_age['qtd_doente']
gp_age['chance_doente'] = gp_age['qtd_doente'] / gp_age['qtd_saudavel']
gp_age['rc_saudavel'] = gp_age['chance_saudavel'] * np.power(gp_age['qtd_saudavel'] / gp_age['total'], -1)
gp_age['rc_doente'] = gp_age['chance_doente'] * np.power(gp_age['qtd_doente'] / gp_age['total'], -1)
gp_age['logito_doente'] = np.log(gp_age['chance_doente'])
gp_age['woe_saudavel'] = np.log(gp_age['rc_saudavel'])
gp_age['woe_doente'] = np.log(gp_age['rc_doente'])
gp_age
# Out:
#                 media_idade  qtd_saudavel  qtd_doente  total  media_doente  \
# cat_age
# (28.999, 45.0]    41.222222            47          16     63      0.253968
# (45.0, 53.0]      50.000000            42          22     64      0.343750
# (53.0, 58.0]      56.211268            32          39     71      0.549296
# (58.0, 62.0]      60.355556            13          32     45      0.711111
# (62.0, 77.0]      66.516667            30          30     60      0.500000
#
#                 chance_saudavel  chance_doente  rc_saudavel  rc_doente  \
# cat_age
# (28.999, 45.0]         2.937500       0.340426     3.937500   1.340426
# (45.0, 53.0]           1.909091       0.523810     2.909091   1.523810
# (53.0, 58.0]           0.820513       1.218750     1.820513   2.218750
# (58.0, 62.0]           0.406250       2.461538     1.406250   3.461538
# (62.0, 77.0]           1.000000       1.000000     2.000000   2.000000
#
#                 logito_doente  woe_saudavel  woe_doente
# cat_age
# ...

# %% [markdown]
# 3. Visualize a informação da bivariada construída acima através de um gráfico da sua escolha.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

ax[0].set_ylabel('Razão de Chances')
ax[0].set_xlabel('Grupo')
ax[0].set_title('Razão de Chances de Doentes e Saudáveis por Grupo de Idade')

sns.lineplot(x=[str(item) for item in gp_age.reset_index()['cat_age']], y=gp_age['rc_doente'], label='Doente', ax=ax[0])
sns.lineplot(x=[str(item) for item in gp_age.reset_index()['cat_age']], y=gp_age['rc_saudavel'], label='Saudável', ax=ax[0])

ax[1].set_ylabel('Quantidade')
ax[1].set_xlabel('Grupo')
ax[1].set_title('Quantidade de Doentes e Saudáveis por Grupo de Idade')

sns.lineplot(x=[str(item) for item in gp_age.reset_index()['cat_age']], y=gp_age['qtd_doente'], label='Doente', ax=ax[1])
sns.lineplot(x=[str(item) for item in gp_age.reset_index()['cat_age']], y=gp_age['qtd_saudavel'], label='Saudável', ax=ax[1])

plt.tight_layout()

plt.show()
